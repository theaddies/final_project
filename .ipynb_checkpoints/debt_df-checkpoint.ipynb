# %%
import pandas as pd
import numpy as np
from numpy import nan

# %%
input_file = 'most-recent-cohorts-all-data-elements-1.csv'
path = './data/'
column_template_2 = 'column_heading_template_earnings.csv'
path2 = './data_documentation/'
input_file_for_debt = 'debt_df.csv'

# %%
df = pd.read_csv(path+input_file, low_memory=False)

# %%
#this converts the columns of the dataframe to the most reasonable data type
df = df.convert_dtypes()

# %%
#This reads in a list of the columns that Matt and I selected
column_heading_df = pd.read_csv(path2 + column_template_2)

# %%
#this is the list of columns that I need to keep for the analysis
filtered_variable_name_list = column_heading_df['VARIABLE NAME'].unique().tolist()
filtered_variable_name_list
# Out:
# ['CIP01BACHL',
#  'CIP04BACHL',
#  'CIP05BACHL',
#  'CIP26BACHL',
#  'CIP52BACHL',
#  'CIP09BACHL',
#  'CIP10BACHL',
#  'CIP11BACHL',
#  'CIP46BACHL',
#  'CIP13BACHL',
#  'CIP15BACHL',
#  'CIP14BACHL',
#  'CIP23BACHL',
#  'CIP19BACHL',
#  'CIP16BACHL',
#  'CIP51BACHL',
#  'CIP54BACHL',
#  'CIP43BACHL',
#  'CIP22BACHL',
#  'CIP24BACHL',
#  'CIP25BACHL',
#  'CIP27BACHL',
#  'CIP47BACHL',
#  'CIP29BACHL',
#  'CIP30BACHL',
#  'CIP03BACHL',
#  'CIP31BACHL',
#  'CIP12BACHL',
#  'CIP38BACHL',
#  'CIP40BACHL',
#  'CIP48BACHL',
#  'CIP42BACHL',
#  'CIP44BACHL',
#  'CIP41BACHL',
#  'CIP45BACHL',
#  'CIP39BACHL',
#  'CIP49BACHL',
#  'CIP50BACHL',
#  'PRGMOFR',
#  'PCIP01',
#  'PCIP04',
#  'PCIP05',
#  'PCIP26',
#  'PCIP52',
#  'PCIP09',
#  'PCIP10',
#  'PCIP11',
#  'PCIP46',
#  'PCIP13',
#  'PCIP15',
#  'PCIP14',
#  'PCIP23',
#  'PCIP19',
#  'PCIP16',
#  'PCIP51',
#  'PCIP54',
#  'PCIP43',
#  'PCIP22',
#  'PCIP24',
#  'PCIP25',
#  'PCIP27',
#  'PCIP47',
#  'PCIP29',
#  'PCIP30',
#  'PCIP03',
#  'PCIP31',
#  'PCIP12',
#  'PCIP38',
#  'PCIP40',
#  'PCIP48',
#  'PCIP42',
#  'PCIP44',
#  'PCIP41',
#  'PCIP45',
#  'PCIP39',
#  'PCIP49',
#  'PCIP50',
#  'SATVR25',
#  'SATMT25',
#  'SATWR25',
#  'ACTCM25',
#  'ACTEN25',
#  'ACTMT25',
#  'ACTWR25',
#  'SATVR75',
#  'SATMT75',
#  'SATWR75',
#  'ACTCM75',
#  'ACTEN75',
#  'ACTMT75',
#  'ACTWR75',
#  'ADM_RATE',
#  'ADM_RATE_ALL',
#  'SAT_AVG',
#  'SAT_AVG_ALL',
#  'SATVRMID',
#  'SATMTMID',
#  'SATWRMID',
#  'ACTCMMID',
#  'ACTENMID',
#  'ACTMTMID',
#  'ACTWRMID',
#  'PCTFLOAN',
#  'FTFTPCTFLOAN_POOLED_SUPP',
#  'LOAN_EVER',
#  'C150_4',
#  'C150_4_POOLED',
#  'DEP_COMP_ORIG_YR6_RT',
#  'WDRAW_ORIG_YR2_RT',
#  'COSTT4_A',
#  'COSTT4_P',
#  'NPT41_OTHER',
#  'NPT41_PRIV',
#  'NPT41_PROG',
#  'NPT41_PUB',
#  'NPT4_048_OTHER',
#  'NPT4_048_PRIV',
#  'NPT4_048_PROG',
#  'NPT4_048_PUB',
#  'NPT45_OTHER',
#  'NPT45_PRIV',
#  'NPT45_PROG',
#  'NPT45_PUB',
#  'NPT42_OTHER',
#  'NPT42_PRIV',
#  'NPT42_PROG',
#  'NPT42_PUB',
#  'NPT4_3075_OTHER',
#  'NPT4_3075_PRIV',
#  'NPT4_3075_PROG',
#  'NPT4_3075_PUB',
#  'NPT43_OTHER',
#  'NPT43_PRIV',
#  'NPT43_PROG',
#  'NPT43_PUB',
#  'NPT4_75UP_OTHER',
#  'NPT4_75UP_PRIV',
#  'NPT4_75UP_PROG',
#  'NPT4_75UP_PUB',
#  'NPT44_OTHER',
#  'NPT44_PRIV',
#  'NPT44_PROG',
#  'NPT44_PUB',
#  'NPT4_PROG',
#  'NPT4_OTHER',
#  'NPT4_PRIV',
#  'NPT4_PUB',
#  'TUITIONFEE_IN',
#  'NUM4_OTHER',
#  'NUM4_PRIV',
#  'NUM4_PROG',
#  'NUM4_PUB',
#  'NUM41_OTHER',
#  'NUM41_PRIV',
#  'NUM41_PROG',
#  'NUM41_PUB',
#  'NUM45_OTHER',
#  'NUM45_PRIV',
#  'NUM45_PROG',
#  'NUM45_PUB',
#  'NUM42_OTHER',
#  'NUM42_PRIV',
#  'NUM42_PROG',
#  'NUM42_PUB',
#  'NUM43_OTHER',
#  'NUM43_PRIV',
#  'NUM43_PROG',
#  'NUM43_PUB',
#  'NUM44_OTHER',
#  'NUM44_PRIV',
#  'NUM44_PROG',
#  'NUM44_PUB',
#  'TUITIONFEE_OUT',
#  'TUITIONFEE_PROG',
#  'CIPTFBSANNUAL1',
#  'CIPTFBS1',
#  'CIPTFBSANNUAL2',
#  'CIPTFBS2',
#  'CIPTFBSANNUAL3',
#  'CIPTFBS3',
#  'CIPTFBSANNUAL4',
#  'CIPTFBS4',
#  'CIPTFBSANNUAL5',
#  'CIPTFBS5',
#  'CIPTFBSANNUAL6',
#  'CIPTFBS6',
#  'PCT10_EARN_WNE_P10',
#  'PCT10_EARN_WNE_P6',
#  'PCT10_EARN_WNE_P8',
#  'PCT25_EARN_WNE_P10',
#  'PCT25_EARN_WNE_P6',
#  'PCT25_EARN_WNE_P8',
#  'PCT75_EARN_WNE_P10',
#  'PCT75_EARN_WNE_P6',
#  'PCT75_EARN_WNE_P8',
#  'PCT90_EARN_WNE_P10',
#  'PCT90_EARN_WNE_P6',
#  'PCT90_EARN_WNE_P8',
#  'MN_EARN_WNE_P6',
#  'MD_EARN_WNE_P10',
#  'MD_EARN_WNE_P6',
#  'MD_EARN_WNE_P8',
#  'COUNT_WNE_INDEP0_P10',
#  'COUNT_WNE_INDEP0_INC1_P10',
#  'COUNT_WNE_INDEP0_P6',
#  'COUNT_WNE_INDEP0_INC1_P6',
#  'COUNT_WNE_MALE0_P10',
#  'COUNT_WNE_MALE0_P6',
#  'COUNT_WNE_INDEP1_P10',
#  'COUNT_WNE_INDEP1_P6',
#  'COUNT_WNE_MALE1_P10',
#  'COUNT_WNE_MALE1_P6',
#  'COUNT_NWNE_P10',
#  'COUNT_NWNE_P6',
#  'COUNT_NWNE_P7',
#  'COUNT_NWNE_P8',
#  'COUNT_NWNE_P9',
#  'COUNT_WNE_P10',
#  'COUNT_WNE_INC3_P10',
#  'COUNT_WNE_INC1_P10',
#  'COUNT_WNE_INC2_P10',
#  'COUNT_WNE_P6',
#  'COUNT_WNE_INC3_P6',
#  'COUNT_WNE_INC1_P6',
#  'COUNT_WNE_INC2_P6',
#  'COUNT_WNE_P7',
#  'COUNT_WNE_P8',
#  'COUNT_WNE_P9',
#  'GT_25K_P10',
#  'GT_25K_P6',
#  'GT_25K_P7',
#  'GT_25K_P8',
#  'GT_25K_P9',
#  'GT_28K_P10',
#  'GT_28K_P6',
#  'GT_28K_P8',
#  'SD_EARN_WNE_P10',
#  'SD_EARN_WNE_P6',
#  'SD_EARN_WNE_P7',
#  'SD_EARN_WNE_P8',
#  'SD_EARN_WNE_P9',
#  'OPEID6',
#  'OPEID',
#  'UNITID',
#  'AVGFACSAL',
#  'CCBASIC',
#  'CCSIZSET',
#  'CCUGPROF',
#  'CITY',
#  'CONTROL',
#  'SCHTYPE',
#  'LOCALE2',
#  'ST_FIPS',
#  'CURROPER',
#  'DISTANCEONLY',
#  'MAIN',
#  'MENONLY',
#  'WOMENONLY',
#  'INSTNM',
#  'INEXPFTE',
#  'ICLEVEL',
#  'LOCALE',
#  'TUITFTE',
#  'NUMBRANCH',
#  'SCH_DEG',
#  'PREDDEG',
#  'PFTFAC',
#  'REGION',
#  'STABBR',
#  'INSTURL',
#  'ZIP',
#  'INC_PCT_H2',
#  'INC_PCT_M1',
#  'INC_PCT_M2',
#  'INC_PCT_H1',
#  'AGE_ENTRY',
#  'FAMINC_IND',
#  'FAMINC',
#  'FSEND_COUNT',
#  'AGE_ENTRY_SQ',
#  'LNFAMINC',
#  'LNFAMINC_IND',
#  'UG',
#  'UGDS',
#  'LN_MEDIAN_HH_INC',
#  'MD_FAMINC',
#  'MEDIAN_HH_INC',
#  'SCUGFFN_POOLED',
#  'AGEGE24',
#  'PCT_GRAD_PROF',
#  'PCT_ASIAN',
#  'PCT_BLACK',
#  'PCT_HISPANIC',
#  'PCT_WHITE',
#  'PCT_BORN_US',
#  'PCT_BA',
#  'UG25ABV',
#  'POVERTY_RATE',
#  'DEPENDENT',
#  'FEMALE',
#  'FIRST_GEN',
#  'MARRIED']

# %%
#duplicate main dataframe
filtered_4_df = df.copy()

# %%
#PREDEG == 3 is the university is predominately a 4 year school.
filtered_4_year_df = filtered_4_df.loc[df['PREDDEG'] == 3, :]
filtered_4_year_df
# Out:
#       UNITID    OPEID  OPEID6  \
# 0     100654   100200    1002
# 1     100663   105200    1052
# 2     100690  2503400   25034
# 3     100706   105500    1055
# 4     100724   100500    1005
# ...      ...      ...     ...
# 6299  492069  4276100   42761
# 6314  492689  1067401   10674
# 6318  492759   638521    6385
# 6319  492801   246100    2461
# 6322  492962   180500    1805
#
#                                                  INSTNM         CITY STABBR  \
# 0                              Alabama A & M University       Normal     AL
# 1                   University of Alabama at Birmingham   Birmingham     AL
# 2                                    Amridge University   Montgomery     AL
# 3                   University of Alabama in Huntsville   Huntsville     AL
# 4                              Alabama State University   Montgomery     AL
# ...                                                 ...          ...    ...
# 6299                         Champion Christian College  Hot Springs     AR
# 6314  Texas Tech University Health Sciences Center-E...      El Paso     TX
# 6318                   Chamberlain University-Louisiana    Jefferson     LA
# 6319  Drury University-College of Continuing Profess...  Springfield     MO
# 6322  Indiana Institute of Technology-College of Pro...   Fort Wayne     IN
#
#              ZIP                                       ACCREDAGENCY  \
# 0          35762  Southern Association of Colleges and Schools C...
# 1     35294-0110  Southern Association of Colleges and Schools C...
# 2     36117-3553  Southern Association of Colleges and Schools C...
# 3          35899  Southern Association of Colleges and Schools C...
# 4     36104-0271  Southern Association of Colleges and Schools C...
# ...          ...                                                ...
# 6299       71913  Transnational Association of Christian College...
# 6314  79905-2827  Southern Association of Colleges and Schools C...
# 6318       70121                         Higher Learning Commission
# 6319       65802                         Higher Learning Commission
# 6322       46803                         Higher Learning Commission
#
#                            INSTURL  \
# 0                    www.aamu.edu/
# 1              https://www.uab.edu
# 2        www.amridgeuniversity.edu
# 3                      www.uah.edu
# 4                    www.alasu.edu
# ...                            ...
# 6299  championchristiancollege.com
# 6314            elpaso.ttuhsc.edu/
# 6318  https://www.chamberlain.edu/
# 6319           www.drury.edu/ccps/
# 6322          cps.indianatech.edu/
#
#                                                  NPCURL  ...  \
# 0     www.aamu.edu/admissions-aid/tuition-fees/net-p...  ...
# 1      https://uab.studentaidcalculator.com/survey.aspx  ...
# 2                      www2.amridgeuniversity.edu:9091/  ...
# 3                                       finaid.uah.edu/  ...
# 4     www.alasu.edu/cost-aid/tuition-costs/net-price...  ...
# ...                                                 ...  ...
# 6299  championchristiancollege.com/NetPriceCalculato...  ...
# 6314  www.depts.ttu.edu/financialaid/netCostCalcHome...  ...
# 6318  https://www.chamberlain.edu/admissions/financi...  ...
# 6319  tcc.ruffalonl.com/Drury%20University/Freshman-...  ...
# 6322                         cps.indianatech.edu/costs/  ...
#
#       OMENRUP_PARTTIME_POOLED_SUPP  FTFTPCTPELL  FTFTPCTFLOAN  UG12MN  G12MN  \
# 0                           0.3193       0.7057        0.7143    5343   1165
# 1                           0.2475       0.3788        0.5350   14445  10498
# 2                           0.2836       1.0000        1.0000     440    527
# 3                           0.2496       0.2707        0.4556    8145   2443
# 4                           0.2621       0.7792        0.7539    4732    642
# ...                            ...          ...           ...     ...    ...
# 6299             PrivacySuppressed       0.0000        0.0000      57   <NA>
# 6314                          <NA>          NaN           NaN     370    471
# 6318                          <NA>          NaN           NaN      21   <NA>
# 6319                        0.3681       0.7619        0.4048    2857   <NA>
# 6322                        0.6939       0.8710        0.8996    6739   <NA>
#
#       SCUGFFN  POOLYRS_FTFTAIDPCT  FTFTPCTPELL_POOLED_SUPP  \
# 0        1288                   2                   0.7083
# 1        2228                   2                   0.3891
# 2           5                   4        PrivacySuppressed
# 3        1341                   2                   0.2378
# 4         951                   2                   0.7684
# ...       ...                 ...                      ...
# 6299       20                   4        PrivacySuppressed
# 6314        0                   4                     <NA>
# 6318     <NA>                <NA>                     <NA>
# 6319       42                   2                   0.7619
# 6322      279                   2                    0.871
#
#       FTFTPCTFLOAN_POOLED_SUPP  SCUGFFN_POOLED
# 0                       0.7287            2698
# 1                       0.5414            4176
# 2            PrivacySuppressed              24
# 3                       0.4402            2544
# 4                       0.7464            2094
# ...                        ...             ...
# 6299         PrivacySuppressed              20
# 6314                      <NA>               0
# 6318                      <NA>            <NA>
# 6319                    0.4048              42
# 6322                    0.8996             279
#
# [2058 rows x 1986 columns]

# %%
filtered_4_year_df.replace(to_replace = 'PrivacySuppressed', value = nan, inplace = True)
# Out:
# C:\Users\thead\anaconda3\lib\site-packages\pandas\core\frame.py:4172: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
#this resets the dataframe to keep only the columns we really want from the list matt and I collected
filtered_4_year_df = filtered_4_year_df[filtered_variable_name_list]
filtered_4_year_df
# Out:
#       CIP01BACHL  CIP04BACHL  CIP05BACHL  CIP26BACHL  CIP52BACHL  CIP09BACHL  \
# 0              1           1           0           1           2           0
# 1              0           0           1           1           2           1
# 2              0           0           0           0           2           0
# 3              0           0           0           1           1           1
# 4              0           0           0           1           1           1
# ...          ...         ...         ...         ...         ...         ...
# 6299           0           0           0           0           0           0
# 6314           0           0           0           0           0           0
# 6318           0           0           0           0           0           0
# 6319           0           0           0           1           2           1
# 6322           0           0           0           0           2           0
#
#       CIP10BACHL  CIP11BACHL  CIP46BACHL  CIP13BACHL  ...      PCT_HISPANIC  \
# 0              1           1           0           1  ...  3.78999996185302
# 1              0           1           0           1  ...  2.02999997138977
# 2              0           0           0           0  ...  6.94000005722046
# 3              0           1           0           1  ...  2.54999995231628
# 4              0           1           0           1  ...  4.09000015258789
# ...          ...         ...         ...         ...  ...               ...
# 6299           0           0           0           0  ...              <NA>
# 6314           0           0           0           0  ...              <NA>
# 6318           0           0           0           0  ...              <NA>
# 6319           0           0           0           1  ...              <NA>
# 6322           0           2           0           0  ...              <NA>
#
#              PCT_WHITE       PCT_BORN_US            PCT_BA  UG25ABV  \
# 0     46.8400001525878  94.7399978637695                13   0.0758
# 1     69.0199966430664              96.5  15.9300003051757   0.2296
# 2     70.8799972534179  94.0899963378906  13.2299995422363   0.8302
# 3     76.3799972534179  95.2699966430664  17.6700000762939   0.1842
# 4     42.6899986267089  94.5299987792968  11.8100004196167   0.0848
# ...                ...               ...               ...      ...
# 6299              <NA>              <NA>              <NA>      NaN
# 6314              <NA>              <NA>              <NA>      NaN
# 6318              <NA>              <NA>              <NA>      NaN
# 6319              <NA>              <NA>              <NA>      NaN
# 6322              <NA>              <NA>              <NA>      NaN
#
#           POVERTY_RATE     DEPENDENT        FEMALE     FIRST_GEN       MARRIED
# 0     14.8800001144409  0.9011299435  0.5640301318  0.3658280922  0.0091023227
# 1     10.9099998474121  0.6785913918  0.6390907397   0.341223671  0.1050866406
# 2     10.6499996185302  0.1047297297  0.6486486486        0.5125  0.2364864865
# 3     9.36999988555908  0.7484303056  0.4763499372  0.3101321586  0.1004604437
# 4     16.9599990844726   0.892571885  0.6134185304  0.3434343434  0.0079872204
# ...                ...           ...           ...           ...           ...
# 6299              <NA>          <NA>          <NA>          <NA>          <NA>
# 6314              <NA>          <NA>          <NA>          <NA>          <NA>
# 6318              <NA>          <NA>          <NA>          <NA>          <NA>
# 6319              <NA>          <NA>          <NA>          <NA>          <NA>
# 6322              <NA>          <NA>          <NA>          <NA>          <NA>
#
# [2058 rows x 302 columns]

# %%
#the names of all columns
column_names = filtered_4_year_df.columns

# %%
#the datatype of all columns
column_types = filtered_4_year_df.dtypes

# %%
#we need all numbers so we need to address teh columns that are strings
filtered_4_year_df.dtypes.unique()
# Out:
# array([Int64Dtype(), dtype('float64'), StringDtype], dtype=object)

# %%
#this is the datatypes that are string that are True.  This is data that should be numbers but are not.
filtered_4_year_df.dtypes == 'string'
# Out:
# CIP01BACHL      False
# CIP04BACHL      False
# CIP05BACHL      False
# CIP26BACHL      False
# CIP52BACHL      False
#                 ...
# POVERTY_RATE     True
# DEPENDENT        True
# FEMALE           True
# FIRST_GEN        True
# MARRIED          True
# Length: 302, dtype: bool

# %%
#this is the name of each column that is a string and should not be
column_types[(column_types == 'string').to_list()].index
# Out:
# Index(['FTFTPCTFLOAN_POOLED_SUPP', 'LOAN_EVER', 'DEP_COMP_ORIG_YR6_RT',
#        'WDRAW_ORIG_YR2_RT', 'PCT10_EARN_WNE_P10', 'PCT10_EARN_WNE_P6',
#        'PCT10_EARN_WNE_P8', 'PCT25_EARN_WNE_P10', 'PCT25_EARN_WNE_P6',
#        'PCT25_EARN_WNE_P8', 'PCT75_EARN_WNE_P10', 'PCT75_EARN_WNE_P6',
#        'PCT75_EARN_WNE_P8', 'PCT90_EARN_WNE_P10', 'PCT90_EARN_WNE_P6',
#        'PCT90_EARN_WNE_P8', 'MN_EARN_WNE_P6', 'MD_EARN_WNE_P10',
#        'MD_EARN_WNE_P6', 'MD_EARN_WNE_P8', 'COUNT_WNE_INDEP0_P10',
#        'COUNT_WNE_INDEP0_INC1_P10', 'COUNT_WNE_INDEP0_P6',
#        'COUNT_WNE_INDEP0_INC1_P6', 'COUNT_WNE_MALE0_P10', 'COUNT_WNE_MALE0_P6',
#        'COUNT_WNE_INDEP1_P10', 'COUNT_WNE_INDEP1_P6', 'COUNT_WNE_MALE1_P10',
#        'COUNT_WNE_MALE1_P6', 'COUNT_NWNE_P10', 'COUNT_NWNE_P6',
#        'COUNT_NWNE_P7', 'COUNT_NWNE_P8', 'COUNT_NWNE_P9', 'COUNT_WNE_P10',
#        'COUNT_WNE_INC3_P10', 'COUNT_WNE_INC1_P10', 'COUNT_WNE_INC2_P10',
#        'COUNT_WNE_P6', 'COUNT_WNE_INC3_P6', 'COUNT_WNE_INC1_P6',
#        'COUNT_WNE_INC2_P6', 'COUNT_WNE_P7', 'COUNT_WNE_P8', 'COUNT_WNE_P9',
#        'GT_25K_P10', 'GT_25K_P6', 'GT_25K_P7', 'GT_25K_P8', 'GT_25K_P9',
#        'GT_28K_P10', 'GT_28K_P6', 'GT_28K_P8', 'SD_EARN_WNE_P10',
#        'SD_EARN_WNE_P6', 'SD_EARN_WNE_P7', 'SD_EARN_WNE_P8', 'SD_EARN_WNE_P9',
#        'CITY', 'INSTNM', 'STABBR', 'INSTURL', 'ZIP', 'INC_PCT_H2',
#        'INC_PCT_M1', 'INC_PCT_M2', 'INC_PCT_H1', 'AGE_ENTRY', 'FAMINC_IND',
#        'FAMINC', 'LN_MEDIAN_HH_INC', 'MD_FAMINC', 'MEDIAN_HH_INC', 'AGEGE24',
#        'PCT_GRAD_PROF', 'PCT_ASIAN', 'PCT_BLACK', 'PCT_HISPANIC', 'PCT_WHITE',
#        'PCT_BORN_US', 'PCT_BA', 'POVERTY_RATE', 'DEPENDENT', 'FEMALE',
#        'FIRST_GEN', 'MARRIED'],
#       dtype='object')

# %%
#to do an earnings analysis of the data we need to know if this column is a string or not.
filtered_4_year_df['MN_EARN_WNE_P6'].dtype
# Out:
# StringDtype

# %%
filtered_4_year_df['MN_EARN_WNE_P6']
# Out:
# 0       28400
# 1       39400
# 2       35400
# 3       40300
# 4       24400
#         ...
# 6299     <NA>
# 6314     <NA>
# 6318     <NA>
# 6319     <NA>
# 6322     <NA>
# Name: MN_EARN_WNE_P6, Length: 2058, dtype: string

# %%
#since this will be y variable there is no sense in keeping rows that have a 0 for the y.  That is meaningless.
filtered_4_year_df['MN_EARN_WNE_P6'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6299     True
# 6314     True
# 6318     True
# 6319     True
# 6322     True
# Name: MN_EARN_WNE_P6, Length: 2058, dtype: bool

# %%
#this drops all columns in the data set that have a 0 for the mean earnings.
filtered_4_year_df = filtered_4_year_df.loc[~filtered_4_year_df['MN_EARN_WNE_P6'].isna()]
filtered_4_year_df
# Out:
#       CIP01BACHL  CIP04BACHL  CIP05BACHL  CIP26BACHL  CIP52BACHL  CIP09BACHL  \
# 0              1           1           0           1           2           0
# 1              0           0           1           1           2           1
# 2              0           0           0           0           2           0
# 3              0           0           0           1           1           1
# 4              0           0           0           1           1           1
# ...          ...         ...         ...         ...         ...         ...
# 5911           0           0           0           0           1           1
# 5912           0           0           0           0           1           0
# 5914           0           0           0           0           0           0
# 5918           0           0           0           1           1           1
# 5931           0           0           0           0           0           0
#
#       CIP10BACHL  CIP11BACHL  CIP46BACHL  CIP13BACHL  ...      PCT_HISPANIC  \
# 0              1           1           0           1  ...  3.78999996185302
# 1              0           1           0           1  ...  2.02999997138977
# 2              0           0           0           0  ...  6.94000005722046
# 3              0           1           0           1  ...  2.54999995231628
# 4              0           1           0           1  ...  4.09000015258789
# ...          ...         ...         ...         ...  ...               ...
# 5911           0           1           0           0  ...              <NA>
# 5912           0           1           0           0  ...              <NA>
# 5914           0           0           0           0  ...              <NA>
# 5918           0           1           0           0  ...              <NA>
# 5931           0           0           0           0  ...              <NA>
#
#              PCT_WHITE       PCT_BORN_US            PCT_BA  UG25ABV  \
# 0     46.8400001525878  94.7399978637695                13   0.0758
# 1     69.0199966430664              96.5  15.9300003051757   0.2296
# 2     70.8799972534179  94.0899963378906  13.2299995422363   0.8302
# 3     76.3799972534179  95.2699966430664  17.6700000762939   0.1842
# 4     42.6899986267089  94.5299987792968  11.8100004196167   0.0848
# ...                ...               ...               ...      ...
# 5911              <NA>              <NA>              <NA>   0.9634
# 5912              <NA>              <NA>              <NA>   0.9291
# 5914              <NA>              <NA>              <NA>   0.4764
# 5918              <NA>              <NA>              <NA>   0.4652
# 5931              <NA>              <NA>              <NA>   0.6026
#
#           POVERTY_RATE     DEPENDENT        FEMALE     FIRST_GEN       MARRIED
# 0     14.8800001144409  0.9011299435  0.5640301318  0.3658280922  0.0091023227
# 1     10.9099998474121  0.6785913918  0.6390907397   0.341223671  0.1050866406
# 2     10.6499996185302  0.1047297297  0.6486486486        0.5125  0.2364864865
# 3     9.36999988555908  0.7484303056  0.4763499372  0.3101321586  0.1004604437
# 4     16.9599990844726   0.892571885  0.6134185304  0.3434343434  0.0079872204
# ...                ...           ...           ...           ...           ...
# 5911              <NA>  0.0812747075  0.6972811618  0.5435338797  0.2844372731
# 5912              <NA>  0.0812747075  0.6972811618  0.5435338797  0.2844372731
# 5914              <NA>  0.5443993035  0.6796285548  0.6864295125  0.0818340104
# 5918              <NA>   0.364461738  0.7336792045  0.5781339439   0.177258971
# 5931              <NA>  0.3365745856  0.7977900552  0.3973442288   0.213038674
#
# [1826 rows x 302 columns]

# %%
filtered_4_year_df.to_csv(path2 + input_file_for_earnings)
